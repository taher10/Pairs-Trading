# %%
from maticalgos.historical import historical

ma = historical('tahersaraf96@gmail.com')

# %%
ma.login("658803")

# %%
import datetime

data = ma.get_data("banknifty", datetime.date(2024,1,15))

# %%
data
# Out:
#          close        date      high       low        oi      open  \
# 0         1.55  2024-01-15       1.8       1.3  210345.0      1.35
# 1          1.3  2024-01-15      1.55       1.3  210345.0       1.5
# 2         1.15  2024-01-15       1.4      1.15  210690.0       1.3
# 3         1.25  2024-01-15      1.25       1.2  210690.0      1.25
# 4          1.2  2024-01-15       1.3       1.2  210690.0       1.3
# ...        ...         ...       ...       ...       ...       ...
# 43667  48198.0  2024-01-15   48207.3   48178.8       nan   48182.6
# 43668  48212.3  2024-01-15   48220.4   48191.2       nan  48199.05
# 43669  48223.7  2024-01-15   48234.6   48209.2       nan  48213.45
# 43670  48232.5  2024-01-15   48232.5  48213.75       nan  48225.55
# 43671  48223.6  2024-01-15  48248.05  48213.95       nan   48216.6
#
#                         symbol      time volume
# 0      BANKNIFTY17JAN2439500PE  09:15:00   9571
# 1      BANKNIFTY17JAN2439500PE  09:16:00   9975
# ...

# %%
data.to_excel('bank_nifty_options.xlsx')
